# %%
import streamlit as st
import tweepy
# from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
# Import API key
from config import consumerKey
from config import consumerSecret
from config import accessToken
from config import accessTokenSecret

# %%
# Create the authentication object
authenticate = tweepy.OAuthHandler(consumerKey, consumerSecret)

# %%
# Set the access token and access token secret
authenticate.set_access_token(accessToken, accessTokenSecret)

# %%
# Creating the API object while passing in the auth information
api = tweepy.API(authenticate, wait_on_rate_limit=True)
api

# %%
posts = api.user_timeline(
    screen_name="rogerfederer", count=100, lang="en", tweet_mode="extended")

# %%
posts
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000025BC90FB2B0>, _json={'created_at': 'Sun Oct 11 16:35:25 +0000 2020', 'id': 1315330172221116418, 'id_str': '1315330172221116418', 'full_text': 'https://t.co/TzQhBeuwML', 'truncated': False, 'display_text_range': [0, 0], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1315330167724802048, 'id_str': '1315330167724802048', 'indices': [0, 23], 'media_url': 'http://pbs.twimg.com/media/EkD90ZGXgAAUmUd.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EkD90ZGXgAAUmUd.jpg', 'url': 'https://t.co/TzQhBeuwML', 'display_url': 'pic.twitter.com/TzQhBeuwML', 'expanded_url': 'https://twitter.com/rogerfederer/status/1315330172221116418/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1242, 'h': 1092, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 1055, 'resize': 'fit'}, 'small': {'w': 680, 'h': 598, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id'
# ...

# %%
search_posts = api.search(
    q="rogerfederer", result_type='recent', count=10, lang="en", tweet_mode="extended")

# %%
search_posts
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000025BC93F9F98>, _json={'created_at': 'Sun Oct 25 23:29:40 +0000 2020', 'id': 1320507852855767041, 'id_str': '1320507852855767041', 'full_text': '@AlexZverev collected his 13th🏆 @bett1hulks reaching the same number of titles like Sergi Bruguera &amp; @TennisHalloFame @KYevgeni had at the same age. \nWhat a coincidence that all 3 players have a winning H2H records vs @rogerfederer :\nBruguera 1-0\nKafelnikov 4-2\nA.Zverev 4-3 https://t.co/fVCjW5QFbN https://t.co/OuqsacFCdg', 'truncated': False, 'display_text_range': [0, 302], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'AlexZverev', 'name': 'Alexander Zverev', 'id': 1151879668854865920, 'id_str': '1151879668854865920', 'indices': [0, 11]}, {'screen_name': 'bett1hulks', 'name': 'bett1_HULKS', 'id': 1265008790484725761, 'id_str': '1265008790484725761', 'indices': [32, 43]}, {'screen_name': 'TennisHalloFame', 'name': 'Tennis Hall of Fame', 'id': 20069768, 'id_st
# ...
