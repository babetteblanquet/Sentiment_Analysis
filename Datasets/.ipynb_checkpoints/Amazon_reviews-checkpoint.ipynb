# %%
import pandas as pd
import gzip

# %%
def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

# %%
def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

# %%
df = getDF('reviews_Grocery_and_Gourmet_Food_5.json.gz')

# %%
df.head()
# Out:
#        reviewerID        asin     reviewerName helpful  \
# 0  A1VEELTKS8NLZB  616719923X  Amazon Customer  [0, 0]
# 1  A14R9XMZVJ6INB  616719923X          amf0001  [0, 1]
# 2  A27IQHDZFQFNGG  616719923X          Caitlin  [3, 4]
# 3  A31QY5TASILE89  616719923X     DebraDownSth  [0, 0]
# 4  A2LWK003FFMCI5  616719923X         Diana X.  [1, 2]
#
#                                           reviewText  overall  \
# 0  Just another flavor of Kit Kat but the taste i...      4.0
# 1  I bought this on impulse and it comes from Jap...      3.0
# 2  Really good. Great gift for any fan of green t...      4.0
# 3  I had never had it before, was curious to see ...      5.0
# 4  I've been looking forward to trying these afte...      4.0
#
#                                              summary  unixReviewTime  \
# 0                                         Good Taste      1370044800
# 1  3.5 stars,  sadly not as wonderful as I had hoped      1400457600
# 2                                               Yum!      1381190400
# 3                             Unexpected flavor meld      1369008000
# 4  Not a very strong tea flavor, but still yummy ...      1369526400
#
#     reviewTime
# 0   06 1, 2013
# 1  05 19, 2014
# 2   10 8, 2013
# 3  05 20, 2013
# 4  05 26, 2013

# %%
df_small = df[:999]
df_small
# Out:
#          reviewerID        asin      reviewerName helpful  \
# 0    A1VEELTKS8NLZB  616719923X   Amazon Customer  [0, 0]
# 1    A14R9XMZVJ6INB  616719923X           amf0001  [0, 1]
# 2    A27IQHDZFQFNGG  616719923X           Caitlin  [3, 4]
# 3    A31QY5TASILE89  616719923X      DebraDownSth  [0, 0]
# 4    A2LWK003FFMCI5  616719923X          Diana X.  [1, 2]
# ..              ...         ...               ...     ...
# 994  A18WPXJTCCWZFR  B00016RH40        Grangranny  [0, 0]
# 995  A15XI2BEGGFEOW  B00016RH40  James "James S."  [0, 0]
# 996  A1DYNEMS8PB7X4  B00016RH40  Meredith H "mbh"  [1, 1]
# 997  A15V074UFQ16YH  B00016RH40     Nancy Presley  [0, 0]
# 998  A379I165C488H8  B00016RH40       N. Ricketts  [5, 6]
#
#                                             reviewText  overall  \
# 0    Just another flavor of Kit Kat but the taste i...      4.0
# 1    I bought this on impulse and it comes from Jap...      3.0
# 2    Really good. Great gift for any fan of green t...      4.0
# 3    I had never had it before, was curious to see ...      5.0
# 4    I've been looking forward to trying these afte...      4.0
# ..                                                 ...      ...
# 994  I will never substitute this Sweet Leaf brand ...      5.0
# 995  I've made my own extract several times but i'm...      5.0
# 996  I switched from Splenda to this stuff about a ...      5.0
# 997  Love this stevia.It is the only brand I use.Wi...      5.0
# 998  I'm telling everybody about SweetLeaf brand st...      5.0
#
#                                                summary  unixReviewTime  \
# 0                                           Good Taste      1370044800
# 1    3.5 stars,  sadly not as wonderful as I had hoped      1400457600
# 2                                                 Yum!      1381190400
# 3                               Unexpected flavor meld      1369008000
# 4    Not a very strong tea flavor, but still yummy ...      1369526400
# ..                                                 ...             ...
# 994          Sweet Leaf is the only Stevia I will buy!      1392249600
# 995                       excellent quality and flavor      1390176000
# 996                       so much better than Splenda!      1397692800
# 997                                      Great product      1404691200
# 998    I'm telling everybody about stevia clear liquid      1370995200
#
#       reviewTime
# 0     06 1, 2013
# 1    05 19, 2014
# 2     10 8, 2013
# 3    05 20, 2013
# 4    05 26, 2013
# ..           ...
# 994  02 13, 2014
# 995  01 20, 2014
# 996  04 17, 2014
# 997   07 7, 2014
# 998  06 12, 2013
#
# [999 rows x 9 columns]

# %%
 df_review = df_small[["reviewText", "overall"]]
df_review
# Out:
#                                             reviewText  overall
# 0    Just another flavor of Kit Kat but the taste i...      4.0
# 1    I bought this on impulse and it comes from Jap...      3.0
# 2    Really good. Great gift for any fan of green t...      4.0
# 3    I had never had it before, was curious to see ...      5.0
# 4    I've been looking forward to trying these afte...      4.0
# ..                                                 ...      ...
# 994  I will never substitute this Sweet Leaf brand ...      5.0
# 995  I've made my own extract several times but i'm...      5.0
# 996  I switched from Splenda to this stuff about a ...      5.0
# 997  Love this stevia.It is the only brand I use.Wi...      5.0
# 998  I'm telling everybody about SweetLeaf brand st...      5.0
#
# [999 rows x 2 columns]

# %%
df_classify = df_review.loc[df_review["overall"] < 5 ]
df_classify
# Out:
#                                             reviewText  overall
# 0    Just another flavor of Kit Kat but the taste i...      4.0
# 1    I bought this on impulse and it comes from Jap...      3.0
# 2    Really good. Great gift for any fan of green t...      4.0
# 4    I've been looking forward to trying these afte...      4.0
# 5    These Kit-kats are very good, but if you're lo...      4.0
# ..                                                 ...      ...
# 978  I was hoping it would be more like the Kraft M...      3.0
# 979  not what you might think but good all the same...      4.0
# 985  Salt is pretty much salt. It's just a little t...      4.0
# 986  Normal Sea Salt. I have about 17 salts and thi...      4.0
# 992  Not as sweet as I expected it to be based on m...      3.0
#
# [299 rows x 2 columns]

# %%
df_classify.count()
# Out:
# reviewText    299
# overall       299
# dtype: int64

# %%
df_classify["reviewText"][986]
# Out:
# 'Normal Sea Salt. I have about 17 salts and this is one of my normal Sea Salts. Nothing fancy about it.'

# %%
df_review.loc[df_review["overall"] < 5, "overall"] = 0
df_review
# Out:
# C:\Users\Babette\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#                                             reviewText  overall
# 0    Just another flavor of Kit Kat but the taste i...      0.0
# 1    I bought this on impulse and it comes from Jap...      0.0
# 2    Really good. Great gift for any fan of green t...      0.0
# 3    I had never had it before, was curious to see ...      5.0
# 4    I've been looking forward to trying these afte...      0.0
# ..                                                 ...      ...
# 994  I will never substitute this Sweet Leaf brand ...      5.0
# 995  I've made my own extract several times but i'm...      5.0
# 996  I switched from Splenda to this stuff about a ...      5.0
# 997  Love this stevia.It is the only brand I use.Wi...      5.0
# 998  I'm telling everybody about SweetLeaf brand st...      5.0
#
# [999 rows x 2 columns]

# %%
df_review.loc[df_review["overall"] == 5, "overall"] = 1
df_review
# Out:
# C:\Users\Babette\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#                                             reviewText  overall
# 0    Just another flavor of Kit Kat but the taste i...      0.0
# 1    I bought this on impulse and it comes from Jap...      0.0
# 2    Really good. Great gift for any fan of green t...      0.0
# 3    I had never had it before, was curious to see ...      1.0
# 4    I've been looking forward to trying these afte...      0.0
# ..                                                 ...      ...
# 994  I will never substitute this Sweet Leaf brand ...      1.0
# 995  I've made my own extract several times but i'm...      1.0
# 996  I switched from Splenda to this stuff about a ...      1.0
# 997  Love this stevia.It is the only brand I use.Wi...      1.0
# 998  I'm telling everybody about SweetLeaf brand st...      1.0
#
# [999 rows x 2 columns]
